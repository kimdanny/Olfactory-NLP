# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#stories 1 contains data we got from adj+nouns iteration. Change to just stories dataset for everything else 
df_stories = pd.read_csv('stories1.csv', '\n')
df_stories.head()

processedData = list(df_stories["col"])

# %%
df_vectors = pd.read_csv('GloVe_cbow_augmented_data_with_backtrans.csv', ',') # change this file name §§§§
df_vectors.drop(df_vectors.columns[0], axis=1,inplace=True)
df_vectors_with_PCA = df_vectors.copy()

df_vectors.head()
df_vectors_with_PCA.head()
# print(df_vectors.shape)GloVe_skipgram
# Out:
#           0          1          2  ...         97         98         99
# 0 -4.961814  13.023991   6.001929  ...  -7.995059  17.008929  10.276027
# 1  2.790306  22.612303  23.208282  ... -15.075478  32.027248  -0.923793
# 2 -4.219720   9.297739  11.590141  ...  -6.654704  12.948126  11.290941
# 3 -0.608154   6.755185   3.451885  ...  -2.152365   5.873356   4.732817
# 4 -0.490175   7.455332   9.666709  ...  -2.830116   5.964099   3.121807
#
# [5 rows x 100 columns]

# %%
#for visualization
import pandas as pd
wiki_lst=[]
title=[]
for story_index, data in enumerate(processedData):
    wiki_lst.append(data)
    title.append(story_index)
print("examine content")
wiki_lst
# Out:
# examine content
# ['smell rotten eggs memorable smell mouth small full assumed embarrassed fess real needless sure',
#  'foul litter smell hit entire smell urine lesser extent whole smell gigantic red litter pan right unfortunately adorable litter pan clean smell dizzy urine strong noxious mix tried cute didnt mention fault drag breathe mouth inhale vow litter pan',
#  'smell coworker fart didnt quiet nauseated cool bottle freshener sprayed whole smell worse long puke',
#  'dragon yelled close smell bad much worse focused',
#  'bush pile smell pungent smeared embarrassed smelled terrible hot sun smell worse humiliating',
#  'dhomeless ordinary typical live urban fair ragged homeless wander stop sudden dirty homeless individual aisle smell alcohol unmistakable musk aisle several physical presence right next smell bad open fresh decided next little late',
#  'stinky next deodorant stunk bad',
#  'much much cologne strong long noticed',
#  'seminar different smell asia several puke behave',
#  'accidental washed tide sport strong much much smell smell alot good strong alot good memorable stupid nice negative',
#  'positive licorice licorice deodorant liked smell positive licorice',
#  'meatshop smell pungent sick overbearing vegetarian',
#  'last large sound green video smell incense musty table leave',
#  'smell spouse liked local fresh blacktop affected smell noticed much spouse allergic dealer couldnt wouldnt',
#  'overwhelming hops pregnant restaurant brews overwhelmed smell hops cross smell possible',
#  'pungent smell memorable recall smell fiesta bombardment good chemical clean new disposable smell light pungent chemical smell complete',
#  'cat ohhh smell litter unpleasant bag cat litter spill need different litter last scooped usual surprised smell strong',
#  'smell many sexualpersonal smell smell important current pleasant high boy nice sweet downside smell wasnt pleasant much bad mouth mean smell guy glad guy silly smell mutual guy murdered minor father stay earl creep',
#  'accidental vegetarian pregnant sensitive particular convinced smell unable finish sick leave small remainder',
#  'pregnant raw sick touch handle sick smell pertained raw steak',
#  'smell smell stale negative smell smell smell depressed reminds great smell uneasy',
#  'aroma recollects antecedent amigo memories scent shampoo many smell old friendwho friendfrom high early best house close shampoo fiancee old frequent dosometimes conjure good bad memories trek initial',
#  'oven first bread unemployed try present save fresh first smell transformative kitchen fun smell fresh smell strong kitchen house major turnaround familys birth son suited stayathome smell fresh',
#  'particular memorable smell cleaner clean gurney white blue smelt lysol strong industrial cleaner last smell',
#  'presence smell stands hospital medicinal smell smell bad smell much dislike',
#  'hospital clean antiseptic strong',
#  'memorable smell smell smell right smell impossible leather mixed',
#  'best young smell happy smell coffee cabin',
#  'smell smell read smell reminds',
#  'smell sunny clear cool reminds end little kid smell react wish hang',
#  'funnel greatest abusive alcoholic father multiple abusive secluded drive scarce hard friendliest white poor didnt video short sister justin jessica house best give single friday drivein theatre funnel fair carnival smell sweet smell funnel',
#  'first real fascinated disgusted equal smell heard older sweet curious wasnt vivid intercourse',
#  'boyfriends cologne memories first cologne popular cologne hollister cologne memories',
#  'alex first son smell strong great great',
#  'smell smell wifes high',
#  'son hospital son smell sterile antiseptic clean linens hit nostrils hard smell much nurse clean sterile smell',
#  'jules particular used particular smell memories',
#  'perfume smell huge scent open bottle favorite smell nana close wonderful wonderful wonderful',
#  'old grandmother berlin beautiful goose pillows clad dark green cotton cold pulled type sure smell right ive experienced smell miss',
#  'perfumed small scared animal slept cindy bunny comfort sleep scared perfume specific kind sweet tangy feeling warmth comfort dab cindys scared smell cindy safe',
#  'best first aware smell wasnt sort first hug goodnight first real conscious sniff fantastic embarrassed good second better smell',
#  'white deceased dad saturday restaurant favorite perfume white recall pretty wonderful didnt sustains wonderful memories nostalgic',
#  'new smell new excited next new new smell hit powerful smell last',
#  'first print particular kind glue distinctive unpleasant smell kind vague licoricekind important accomplishment scent stuck',
#  'new smell memorable smell new smell new smell first new happy proud',
#  'new crv first strong new smell new distinct pleasant newness professional excited smell smell right excitement',
#  'fresh new confident able new actual meet deep stick felt clean fresh new rest',
#  'memories germany big smell memories germany kinda depressed happy',
#  'smell poconos house smell open smell child memories',
#  'house younger bake busy hard hang house house house smell best smell',
#  'hay farmer barn saddle barn smell hay smell hay matter house strong',
#  'house house first couple house amazing smelled good sweet smell sickly sweet',
#  'local joint dad small smell dough cheese scrumptious entree pizza table smell pizza',
#  'heartache smell funeral many memories hurt dad smell bury',
#  'smell smell catches smell open new swimming float smell big huge bins super retail swimming pool smell hint cool imagine little stress reliever small smell smell healthy smell',
#  'hard small palestine zaatar mix herbs olive smell herbs stairwell wonderful full new close whiff herbs nostalgic heartbreaking hungry lonesome lucky strong hard',
#  'gratitude smell fresh read johnny gun dalton trumbo horrified upset grateful able hear speak outside summertime mown sun intense gratitude able horror warfare smell fresh child simpler',
#  'star jasmine hawaii early hawaii adjacent little boutique enormous star jasmine nightowl late open sweet exotic fragrance jasmine laptop whole memorable last true smell star jasmine',
#  'sprung live first plow spread negative smell fresh new warmer fresh new',
#  'smell lavender lavender smell lavender sleep smell lavender smell lavender reminds',
#  'tropical coconut smell coconut wash bahamas teenager first scent sweet tropical great memories smell wash coconut bahamas',
#  'sunday brunch sunday grandpas house smell easy eggs homemade hash browns experienced smell squish bench wall grandpa leftover macaronis pepper happy',
#  'new smell elementary new certain smell early first meeting new new',
#  'memorable smell house old house smell caramel scent reminds child babysitter miss live united babushka lunch excited',
#  'sunset fond memories front house fresh clean pure favorite sun peaceful beautiful',
#  'new smell new smell new new nice first sat smell excited anxious drive',
#  'new smell son born smell new smell smell son fresh new kind new smell different wonderful',
#  'smell steak steak last smell great hungry smell steak steak salt pepper garlic smell good',
#  'bacon smell bacon cafeteria bacon bacon amazing large smell hungry bacon happy smell cant',
#  'sandwich baked breadan unforgettable small sandwich baked bread house first mesmerized wonderful smell overall comfort warmth appetite',
#  'subway open smell resembles much funny wonderful smell sure opens appetite',
#  'fake smellstill delicious first subway restaurant amazing smell fresh baked hungry appetizing smell fake smell subway didnt lessen best',
#  'sunday italian great aunt focus smell homemade italian cooked great aunt sunday smell tomato particular pretty perverse smell house tomato aromatic garlicbasil oregano smell garlic delicious fried hungry reflex delicious smell italian',
#  'delicious sourdough best ive smelt hungry',
#  'ribs greatest god earth middle desert southern california cellular ride small smell fresh ribs local bbq shack mouth hadnt eaten stressful viceral cartoon trail pulled',
#  'noble everyday noble cafe favorite baked powerful smell whole matter hungry eat',
#  'spaghetti spaghetti smell good smell mouth pleasant',
#  'great last smell charcoal juice hot charcoal best top grill fantastic growl',
#  'match smell old dad beat didnt bandaid full dont spite dad herr dad nazi inquisitor match smell match smell',
#  'fresh new first donut smell fresh baked good',
#  'banana joy smell first aunt homemade banana delicious smell experienced house increased banana rejuvenate smell aunt homemade banana first',
#  'bunny smell smell adopt hay',
#  'good wanted',
#  'cupcakes favorite yankee past smell smell smell strong',
#  'new smell michigan meet suv new strongest new smell clear',
#  'new new memorable new smell shiny novel crisp clean',
#  'new smell smell new great smell new perfect smell fresh unique smell smell mixes best possible smell smell',
#  'smell new new new sure smell memorable happy new yugioh excited rare smell new particular smell positive',
#  'dad young smell strong smell bad odd smell dad hug smell much stronger child dad first smell hit smell dad good smell good memories dad',
#  'favorite last close smell warm fresh hungry eat bread breads ate good satisfied breads',
#  'little younger grandma grandpas italian open late open barbie counter smell kitchen fresh italian smell entire full delicious mouth entire great first grandma mini loaf delicious',
#  'sooo good memorable last good',
#  'red velvet small hole enjoy unique smell hit got noticed beautiful backless red dress lipstick aroma',
#  'wonderful new york new york many incredible smell barbecue ribs great cookie smell amazing hot oven fresh hot melt mouth scent enough warm yummy',
#  'best beautiful girl aisle smell incredible distinct unable weird smell incredible stuck compliment applied walked deep amazing smell',
#  'new smell particular smell first new hit new smell smell assembly new',
#  'new marc jacobs mom ebay cheaper nervous fake spent open smell bursting whole real',
#  'new first first shipping new excited little nervous first',
#  'smell much understood true skin smell bad sprayed smell enticing old enough significant grasp',
#  'reborn first steamdot finest alaska first noticed smell twentyfive smell good portland roast espresso much richer complex starbucks dead smell alive sparkling spice associated espresso inhaling cup magnitude greater sort aroma drowns']

# %% [markdown]
# ##Without PCA

# %%
from sklearn.preprocessing import normalize
data_scaled = normalize(df_vectors)
data_scaled = pd.DataFrame(data_scaled, columns= df_vectors.columns)
data_scaled.head()
# Out:
#           0         1         2  ...        97        98        99
# 0 -0.046957  0.123255  0.056800  ... -0.075663  0.160967  0.097249
# 1  0.012090  0.097974  0.100557  ... -0.065319  0.138768 -0.004003
# 2 -0.031230  0.068812  0.085778  ... -0.049251  0.095828  0.083564
# 3 -0.008010  0.088972  0.045464  ... -0.028349  0.077357  0.062335
# 4 -0.005308  0.080735  0.104682  ... -0.030648  0.064586  0.033806
#
# [5 rows x 100 columns]

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10, 7))  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(data_scaled, method='ward'))
plt.axhline(y=1, color='r', linestyle='--')

# %%
#Tried to get sub cluster heirarchies
# from sklearn.cluster import AgglomerativeClustering
# import csv


# def initialize_cluster_dict(): 
#   story_cluster_dict = {}
#   for story in processedData: 
#     story_cluster_dict[story] = []
#   return story_cluster_dict

# def add_to_clusters(labels, dictionary): 
#    for story_index, label in enumerate(labels): 
#      curr_story = df_stories.iloc[story_index][0]
#      dictionary[curr_story].append(label)


# def get_sub_clustering_info(clusters, story_cluster_dict): 
#   for i in clusters: 
#     cluster = AgglomerativeClustering(n_clusters=i, affinity='euclidean', linkage='ward')  
#     labels = cluster.fit_predict(data_scaled)
#     add_to_clusters(labels,story_cluster_dict)

# def write_dictionary_to_file(story_cluster_dict): 
#   with open('CBOW_HCA_subclusters.csv', mode='w') as clusters:
#     cluster_writer = csv.writer(clusters, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
#     for story in story_cluster_dict:
#       labels = story_cluster_dict[story]
#       cluster_writer.writerow([story, labels])

# story_cluster_dict = initialize_cluster_dict()
# clusters = [2, 4,8]
# get_sub_clustering_info(clusters, story_cluster_dict )
# write_dictionary_to_file(story_cluster_dict)

# %%
#TRYING Two CLUSTERS
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=4 ,affinity='euclidean', linkage='ward')  
labels = cluster.fit_predict(data_scaled)
wiki_cl=pd.DataFrame(list(zip(title,labels)),columns=['title','cluster'])
labels
print(len(labels))
# Out:
# 439

# %%
from wordcloud import WordCloud
result={'cluster':labels,'wiki':wiki_lst}
result=pd.DataFrame(result)
for k in range(0,4):
    s=result[result.cluster==k]
    text=s['wiki'].str.cat(sep=' ')
    text=text.lower()
    text=' '.join([word for word in text.split() if word != "smell" and word != "smelled" and word != "really" and word != "remember"])

    wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
    print('Cluster: {}'.format(k))
    print('Titles')
    titles=wiki_cl[wiki_cl.cluster==k]['title']
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()
# Out:
# Cluster: 0
# Titles
# Cluster: 1
# Titles
# Cluster: 2
# Titles
# Cluster: 3
# Titles

# %%
labels
import csv
with open('CBOW_backtrans_with_adj_noun_HCA_clusters_2_withoutPCA.csv', mode='w') as clusters:
  cluster_writer = csv.writer(clusters, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
  for story_index, label in enumerate(labels): 
    cluster_writer.writerow([df_stories.iloc[story_index][0], label])

# %% [markdown]
# ##With PCA

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# standardise the data
scaler = StandardScaler()
df_vectors_std = scaler.fit_transform(df_vectors_with_PCA)

# get optimal number of components 
pca = PCA()
pca.fit(df_vectors_std)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance'); # 45

noComponents = 0 # 0.9 is our baseline
for element in np.cumsum(pca.explained_variance_ratio_):
  noComponents = noComponents + 1
  if element >= 0.9:
    break
print(noComponents)
# Out:
# 43

# %%
pca = PCA(n_components=noComponents)

pca.fit(df_vectors_std)

pca.transform(df_vectors_std)

scores_pca = pca.transform(df_vectors_std)

# %%
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(10, 7))  
plt.title("Dendrograms")  
dend = shc.dendrogram(shc.linkage(scores_pca, method='ward'))

# %%
#TRYING TWO CLUSTERS
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=4, affinity='euclidean', linkage='ward')  
labels = cluster.fit_predict(scores_pca)
wiki_cl=pd.DataFrame(list(zip(title,labels)),columns=['title','cluster'])
labels
print(len(labels))
# Out:
# 439

# %%
from wordcloud import WordCloud
result={'cluster':labels,'wiki':wiki_lst}
result=pd.DataFrame(result)
for k in range(0,4):
    s=result[result.cluster==k]
    text=s['wiki'].str.cat(sep=' ')
    text=text.lower()
    text=' '.join([word for word in text.split() if word != "smell" and word != "smelled" and word != "really"])

    wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
    print('Cluster: {}'.format(k))
    print('Titles')
    titles=wiki_cl[wiki_cl.cluster==k]['title']
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    name = "CBOW_Iteration_3_PCA" + str(k) + ".png"
    plt.savefig(name)
    plt.show()
# Out:
# Cluster: 0
# Titles
# Cluster: 1
# Titles
# Cluster: 2
# Titles
# Cluster: 3
# Titles

# %%
labels
import csv
with open('clusters_adj_noun_3_with_PCA_CBOW_HCA_with_backtrans.csv', mode='w') as clusters:
  cluster_writer = csv.writer(clusters, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
  for story_index, label in enumerate(labels): 
    cluster_writer.writerow([df_stories.iloc[story_index][0], label])

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import silhouette_samples
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# %%
labels_withoutPCA = cluster.fit_predict(data_scaled)
labels_withPCA = cluster.fit_predict(scores_pca)

# %% [markdown]
# ##Silhouette Coefficient

# %% [markdown]
# ### Without PCA

# %%
silhouette_vals = silhouette_samples(data_scaled, labels_withoutPCA)

# %% [markdown]
# ### With PCA

# %%
silhouette_vals = silhouette_samples(scores_pca, labels_withPCA)
silhouette_vals

# %% [markdown]
# ##Calinski-Harabasz Index

# %% [markdown]
# ### Without PCA

# %%
calinski_harabasz_val = calinski_harabasz_score(data_scaled, labels_withoutPCA)

# %% [markdown]
# ### With PCA

# %%
calinski_harabasz_val = calinski_harabasz_score(scores_pca, labels_withPCA)
calinski_harabasz_val

# %% [markdown]
# ##Davies-Bouldin Index

# %% [markdown]
# ### Without PCA

# %%
davies_bouldin_val = davies_bouldin_score(data_scaled, labels_withoutPCA)

# %% [markdown]
# ### With PCA

# %%
davies_bouldin_val = davies_bouldin_score(scores_pca, labels_withPCA)
davies_bouldin_val
